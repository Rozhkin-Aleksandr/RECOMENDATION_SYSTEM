# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Загрузка данных

# %% [markdown]
# Скачать датасет можно по ссылке: https://www.kaggle.com/datasets/saurabhshahane/music-dataset-1950-to-2019.

# %%
data = pd.read_csv('tcc_ceds_music.csv', header=0)
data
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# 2              1950      pop
# 3              1950      pop
# 4              1950      pop
# ...             ...      ...
# 28367          2019  hip hop
# 28368          2019  hip hop
# 28369          2019  hip hop
# 28370          2019  hip hop
# 28371          2019  hip hop
#
#                                                   lyrics  len    dating  \
# 0      hold time feel break feel untrue convince spea...   95  0.000598
# 1      believe drop rain fall grow believe darkest ni...   51  0.035537
# 2      sweetheart send letter goodbye secret feel bet...   24  0.002770
# 3      kiss lips want stroll charm mambo chacha merin...   54  0.048249
# 4      till darling till matter know till dream live ...   48  0.001350
# ...                                                  ...  ...       ...
# 28367  cause fuck leave scar tick tock clock come kno...   78  0.001350
# 28368  minks things chain ring braclets yap fame come...   67  0.001284
# 28369  get ban get ban stick crack relax plan attack ...   77  0.001504
# 28370  check check yeah yeah hear thing call switch g...   67  0.001196
# 28371  remix killer alive remix thriller trap bitch s...   83  0.001012
#
#        violence  world/life  ...   sadness  feelings  danceability  loudness  \
# 0      0.063746    0.000598  ...  0.380299  0.117175      0.357739  0.454119
# 1      0.096777    0.443435  ...  0.001284  0.001284      0.331745  0.647540
# 2      0.002770    0.002770  ...  0.002770  0.225422      0.456298  0.585288
# 3      0.001548    0.001548  ...  0.225889  0.001548      0.686992  0.744404
# 4      0.001350    0.417772  ...  0.068800  0.001350      0.291671  0.646489
# ...         ...         ...  ...       ...       ...           ...       ...
# 28367  0.001350    0.001350  ...  0.065664  0.001350      0.889527  0.759711
# 28368  0.001284    0.035338  ...  0.001284  0.001284      0.662082  0.789580
# 28369  0.154302    0.168988  ...  0.001504  0.001504      0.663165  0.726970
# 28370  0.001196    0.001196  ...  0.001196  0.001196      0.883028  0.786888
# 28371  0.075202    0.001012  ...  0.001012  0.033995      0.828875  0.674794
#
#        acousticness  instrumentalness   valence    energy       topic  \
# 0          0.997992          0.901822  0.339448  0.137110     sadness
# 1          0.954819          0.000002  0.325021  0.263240  world/life
# 2          0.840361          0.000000  0.351814  0.139112       music
# 3          0.083935          0.199393  0.775350  0.743736    romantic
# 4          0.975904          0.000246  0.597073  0.394375    romantic
# ...             ...               ...       ...       ...         ...
# 28367      0.062549          0.000000  0.751649  0.695686     obscene
# 28368      0.004607          0.000002  0.922712  0.797791     obscene
# 28369      0.104417          0.000001  0.838211  0.767761     obscene
# 28370      0.007027          0.000503  0.508450  0.885882     obscene
# 28371      0.015862          0.000000  0.475474  0.492477     obscene
#
#             age
# 0      1.000000
# 1      1.000000
# 2      1.000000
# 3      1.000000
# 4      1.000000
# ...         ...
# 28367  0.014286
# 28368  0.014286
# 28369  0.014286
# 28370  0.014286
# 28371  0.014286
#
# [28372 rows x 31 columns]

# %% [markdown]
# # Первичный анализ данных

# %%
names_counts = data.artist_name.value_counts()
names_counts.describe()
# Out:
# count    5426.000000
# mean        5.228898
# std         9.209810
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       190.000000
# Name: count, dtype: float64

# %%
# удалим всех артистов, у которых меньше 5 песен, они будут портить предсказание

names_counts_idx = names_counts[names_counts>=5].index

data['artist_name'] = data['artist_name'].apply(lambda x : x if x in names_counts_idx else None)

# %%
data = data.dropna()

# %%
# создаем датафрейм признаков, куда не включаем текстовые признаки
X = data.drop(['Unnamed: 0', 'track_name', 'lyrics', 'dating', 'topic'], axis=1)

# %%
X
# Out:
#           artist_name  release_date    genre  len  violence  world/life  \
# 1       frankie laine          1950      pop   51  0.096777    0.443435
# 5          perry como          1950      pop   98  0.420685    0.001053
# 7       johnny mathis          1950      pop   21  0.002506    0.336056
# 11     the chordettes          1951      pop   38  0.001645    0.001645
# 12      frankie laine          1951      pop  173  0.244358    0.083570
# ...               ...           ...      ...  ...       ...         ...
# 28360     nappy roots          2019  hip hop   74  0.125810    0.353286
# 28364   nipsey hussle          2019  hip hop   88  0.001096    0.001096
# 28365     nappy roots          2019  hip hop  109  0.000810    0.000810
# 28367         mack 10          2019  hip hop   78  0.001350    0.001350
# 28371           jeezy          2019  hip hop   83  0.075202    0.001012
#
#        night/time  shake the audience  family/gospel  romantic  ...  \
# 1        0.001284            0.001284       0.027007  0.001284  ...
# 5        0.074078            0.001053       0.001053  0.001053  ...
# 7        0.002506            0.002506       0.002506  0.176861  ...
# 11       0.397490            0.001645       0.001645  0.001645  ...
# 12       0.000627            0.013375       0.022181  0.000627  ...
# ...           ...                 ...            ...       ...  ...
# 28360    0.001196            0.001196       0.001196  0.001196  ...
# 28364    0.001096            0.033829       0.001096  0.001096  ...
# 28365    0.000810            0.000810       0.000810  0.000810  ...
# 28367    0.001350            0.001350       0.001350  0.001350  ...
# 28371    0.001012            0.001012       0.001012  0.001012  ...
#
#        like/girls   sadness  feelings  danceability  loudness  acousticness  \
# 1        0.001284  0.001284  0.001284      0.331745  0.647540      0.954819
# 5        0.001053  0.128292  0.001053      0.689158  0.685588      0.898594
# 7        0.002506  0.062602  0.002506      0.379400  0.529421      0.925703
# 11       0.001645  0.001645  0.001645      0.265677  0.622260      0.988956
# 12       0.000627  0.000627  0.032581      0.522365  0.528729      0.852409
# ...           ...       ...       ...           ...       ...           ...
# 28360    0.029702  0.001196  0.001196      0.546193  0.764967      0.182730
# 28364    0.001096  0.001096  0.001096      0.635005  0.851755      0.014156
# 28365    0.000810  0.000810  0.000810      0.766057  0.773325      0.037348
# 28367    0.001350  0.065664  0.001350      0.889527  0.759711      0.062549
# 28371    0.001012  0.001012  0.033995      0.828875  0.674794      0.015862
#
#        instrumentalness   valence    energy       age
# 1              0.000002  0.325021  0.263240  1.000000
# 5              0.000000  0.768137  0.549535  1.000000
# 7              0.000072  0.373454  0.192167  1.000000
# 11             0.000000  0.058739  0.111083  0.985714
# 12             0.000000  0.408491  0.153127  0.985714
# ...                 ...       ...       ...       ...
# 28360          0.000000  0.751649  0.698689  0.014286
# 28364          0.000000  0.735161  0.913911  0.014286
# 28365          0.000000  0.682605  0.855851  0.014286
# 28367          0.000000  0.751649  0.695686  0.014286
# 28371          0.000000  0.475474  0.492477  0.014286
#
# [21536 rows x 26 columns]

# %%
# One-Hot кодируем жанр и имя артиста
X_t = pd.concat([X.drop(['artist_name', 'genre'], axis=1), pd.get_dummies(X['artist_name']), pd.get_dummies(X['genre'])], axis=1)

# %%
X_t
# Out:
#        release_date  len  violence  world/life  night/time  \
# 1              1950   51  0.096777    0.443435    0.001284
# 5              1950   98  0.420685    0.001053    0.074078
# 7              1950   21  0.002506    0.336056    0.002506
# 11             1951   38  0.001645    0.001645    0.397490
# 12             1951  173  0.244358    0.083570    0.000627
# ...             ...  ...       ...         ...         ...
# 28360          2019   74  0.125810    0.353286    0.001196
# 28364          2019   88  0.001096    0.001096    0.001096
# 28365          2019  109  0.000810    0.000810    0.000810
# 28367          2019   78  0.001350    0.001350    0.001350
# 28371          2019   83  0.075202    0.001012    0.001012
#
#        shake the audience  family/gospel  romantic  communication   obscene  \
# 1                0.001284       0.027007  0.001284       0.001284  0.001284
# 5                0.001053       0.001053  0.001053       0.001053  0.001053
# 7                0.002506       0.002506  0.176861       0.002506  0.002506
# 11               0.001645       0.001645  0.001645       0.066201  0.001645
# 12               0.013375       0.022181  0.000627       0.109129  0.458984
# ...                   ...            ...       ...            ...       ...
# 28360            0.001196       0.001196  0.001196       0.001196  0.040241
# 28364            0.033829       0.001096  0.001096       0.001096  0.733959
# 28365            0.000810       0.000810  0.000810       0.000810  0.394272
# 28367            0.001350       0.001350  0.001350       0.001350  0.391651
# 28371            0.001012       0.001012  0.001012       0.001012  0.754444
#
#        ...  ziggy marley  ziggy marley & the melody makers  zz top  blues  \
# 1      ...         False                             False   False  False
# 5      ...         False                             False   False  False
# 7      ...         False                             False   False  False
# 11     ...         False                             False   False  False
# 12     ...         False                             False   False  False
# ...    ...           ...                               ...     ...    ...
# 28360  ...         False                             False   False  False
# 28364  ...         False                             False   False  False
# 28365  ...         False                             False   False  False
# 28367  ...         False                             False   False  False
# 28371  ...         False                             False   False  False
#
#        country  hip hop   jazz    pop  reggae   rock
# 1        False    False  False   True   False  False
# 5        False    False  False   True   False  False
# 7        False    False  False   True   False  False
# 11       False    False  False   True   False  False
# 12       False    False  False   True   False  False
# ...        ...      ...    ...    ...     ...    ...
# 28360    False     True  False  False   False  False
# 28364    False     True  False  False   False  False
# 28365    False     True  False  False   False  False
# 28367    False     True  False  False   False  False
# 28371    False     True  False  False   False  False
#
# [21536 rows x 1612 columns]

# %%
X_t = X_t.reset_index()
data = data.reset_index()
X_t = X_t.reset_index()
data = data.reset_index()

# %%
# нормируем дату и длину песни
X_t[['release_date', 'len']]= MinMaxScaler().fit(X_t[['release_date', 'len']].to_numpy()).set_output(transform='pandas').transform(X_t[['release_date', 'len']].to_numpy())

# %%
X_t
# Out:
#        level_0  index  release_date       len  violence  world/life  \
# 0            0      1      0.000000  0.252525  0.096777    0.443435
# 1            1      5      0.000000  0.489899  0.420685    0.001053
# 2            2      7      0.000000  0.101010  0.002506    0.336056
# 3            3     11      0.014493  0.186869  0.001645    0.001645
# 4            4     12      0.014493  0.868687  0.244358    0.083570
# ...        ...    ...           ...       ...       ...         ...
# 21531    21531  28360      1.000000  0.368687  0.125810    0.353286
# 21532    21532  28364      1.000000  0.439394  0.001096    0.001096
# 21533    21533  28365      1.000000  0.545455  0.000810    0.000810
# 21534    21534  28367      1.000000  0.388889  0.001350    0.001350
# 21535    21535  28371      1.000000  0.414141  0.075202    0.001012
#
#        night/time  shake the audience  family/gospel  romantic  ...  \
# 0        0.001284            0.001284       0.027007  0.001284  ...
# 1        0.074078            0.001053       0.001053  0.001053  ...
# 2        0.002506            0.002506       0.002506  0.176861  ...
# 3        0.397490            0.001645       0.001645  0.001645  ...
# 4        0.000627            0.013375       0.022181  0.000627  ...
# ...           ...                 ...            ...       ...  ...
# 21531    0.001196            0.001196       0.001196  0.001196  ...
# 21532    0.001096            0.033829       0.001096  0.001096  ...
# 21533    0.000810            0.000810       0.000810  0.000810  ...
# 21534    0.001350            0.001350       0.001350  0.001350  ...
# 21535    0.001012            0.001012       0.001012  0.001012  ...
#
#        ziggy marley  ziggy marley & the melody makers  zz top  blues  country  \
# 0             False                             False   False  False    False
# 1             False                             False   False  False    False
# 2             False                             False   False  False    False
# 3             False                             False   False  False    False
# 4             False                             False   False  False    False
# ...             ...                               ...     ...    ...      ...
# 21531         False                             False   False  False    False
# 21532         False                             False   False  False    False
# 21533         False                             False   False  False    False
# 21534         False                             False   False  False    False
# 21535         False                             False   False  False    False
#
#        hip hop   jazz    pop  reggae   rock
# 0        False  False   True   False  False
# 1        False  False   True   False  False
# 2        False  False   True   False  False
# 3        False  False   True   False  False
# 4        False  False   True   False  False
# ...        ...    ...    ...     ...    ...
# 21531     True  False  False   False  False
# 21532     True  False  False   False  False
# 21533     True  False  False   False  False
# 21534     True  False  False   False  False
# 21535     True  False  False   False  False
#
# [21536 rows x 1614 columns]

# %% [markdown]
# # Создание модели

# %%
knn = NearestNeighbors( algorithm='brute')
knn.fit(X_t)
# Out:
# NearestNeighbors(algorithm='brute')

# %% [markdown]
# # Тестирование

# %%
# функция для тестирования
def predict(artist_name, track_name, n_neighb):
    
    i = data[data['track_name']==track_name].iloc[0,0]
    d, ind = knn.kneighbors(X_t.iloc[i, :].to_numpy().reshape(1,-1), n_neighbors=n_neighb+1)
    print(data.iloc[i, 3:7])
    print('='*30)
    for i in ind[0][1:]:
        print(data.iloc[i, 3:7])
        print('-'*30)

# %%
data[data['artist_name']=='the beatles']
# Out:
#        level_0  index  Unnamed: 0  artist_name                   track_name  \
# 18256    18256  23629       70849  the beatles            not a second time
# 18257    18257  23630       70854  the beatles           all i've got to do
# 18258    18258  23631       70858  the beatles  you really got a hold on me
# 18259    18259  23632       70861  the beatles           till there was you
# 18260    18260  23633       70862  the beatles                all my loving
# ...        ...    ...         ...          ...                          ...
# 19530    19530  25093       75088  the beatles              long tall sally
# 19553    19553  25123       75170  the beatles             i call your name
# 19560    19560  25131       75191  the beatles                     this boy
# 19568    19568  25142       75232  the beatles                    yes it is
# 20039    20039  25722       76633  the beatles                    real love
#
#        release_date genre                                             lyrics  \
# 18256          1963  rock  know wonder change mind reason change give lin...
# 18257          1963  rock  want yeah phone come run home yeah want kiss y...
# 18258          1963  rock  like think treat badly madly hold hold baby wa...
# 18259          1963  rock  bell hear ring hear till bird wing till music ...
# 18260          1963  rock  close eye kiss tomorrow miss remember true awa...
# ...             ...   ...                                                ...
# 19530          1988  rock  go tell aunt uncle say miss baby yeeeeh baby w...
# 19553          1988  rock  blame unfair sleep night go weep night know kn...
# 19560          1988  rock  take away regret someday want good want want t...
# 19568          1988  rock  wear tonight remember say tonight color baby w...
# 20039          1996  rock  little plan scheme lose like forget dream wait...
#
#        len    dating  ...   sadness  feelings  danceability  loudness  \
# 18256   24  0.002105  ...  0.002105  0.002105      0.443301  0.657847
# 18257   29  0.001815  ...  0.001815  0.038473      0.463880  0.650104
# 18258   45  0.100844  ...  0.001316  0.001316      0.337160  0.675512
# 18259   11  0.004785  ...  0.004785  0.004785      0.720568  0.558162
# 18260   22  0.002288  ...  0.041517  0.002288      0.383732  0.690537
# ...    ...       ...  ...       ...       ...           ...       ...
# 19530   51  0.319836  ...  0.001316  0.094508      0.347991  0.732277
# 19553   23  0.002632  ...  0.002632  0.147428      0.680494  0.733277
# 19560   15  0.003289  ...  0.388454  0.124520      0.648002  0.618747
# 19568   45  0.030718  ...  0.001196  0.001196      0.381566  0.704151
# 20039   59  0.000923  ...  0.083807  0.430151      0.354489  0.727790
#
#        acousticness  instrumentalness   valence    energy       topic  \
# 18256      0.213855          0.000000  0.965993  0.817812  world/life
# 18257      0.217871          0.000000  0.881492  0.579566       music
# 18258      0.527108          0.000000  0.683636  0.388369    romantic
# 18259      0.793172          0.000000  0.641385  0.338318       music
# 18260      0.207831          0.000000  0.903133  0.563550    romantic
# ...             ...               ...       ...       ...         ...
# 19530      0.209839          0.004372  0.920651  0.770764  night/time
# 19553      0.314256          0.000123  0.967024  0.691682  night/time
# 19560      0.213855          0.000016  0.700124  0.337317     sadness
# 19568      0.640562          0.000000  0.414674  0.329308  world/life
# 20039      0.054216          0.016296  0.408491  0.671661    feelings
#
#             age
# 18256  0.814286
# 18257  0.814286
# 18258  0.814286
# 18259  0.814286
# 18260  0.814286
# ...         ...
# 19530  0.457143
# 19553  0.457143
# 19560  0.457143
# 19568  0.457143
# 20039  0.342857
#
# [66 rows x 33 columns]

# %%
predict('the beatles', "and i love her", 10)
# Out:
# artist_name        the beatles
# track_name      and i love her
# release_date              1964
# genre                     rock
# Name: 18284, dtype: object
# ==============================
# artist_name             the beatles
# track_name      i'll follow the sun
# release_date                   1964
# genre                          rock
# Name: 18283, dtype: object
# ------------------------------
# artist_name                        the kinks
# track_name      all day and all of the night
# release_date                            1964
# genre                                   rock
# Name: 18285, dtype: object
# ------------------------------
# artist_name              the beatles
# track_name      things we said today
# release_date                    1964
# genre                           rock
# Name: 18286, dtype: object
# ------------------------------
# artist_name     the rolling stones
# track_name           not fade away
# release_date                  1964
# genre                         rock
# Name: 18282, dtype: object
# ------------------------------
# artist_name           the beatles
# track_name      what you're doing
# release_date                 1964
# genre                        rock
# Name: 18281, dtype: object
# ------------------------------
# artist_name          the beatles
# track_name      i'll cry instead
# release_date                1964
# genre                       rock
# Name: 18287, dtype: object
# ------------------------------
# artist_name       the beatles
# track_name      words of love
# release_date             1964
# genre                    rock
# Name: 18288, dtype: object
# ------------------------------
# artist_name     the rolling stones
# track_name      time is on my side
# release_date                  1964
# genre                         rock
# Name: 18280, dtype: object
# ------------------------------
# artist_name         the beatles
# track_name      any time at all
# release_date               1964
# genre                      rock
# Name: 18289, dtype: object
# ------------------------------
# artist_name                            elvis presley
# track_name      anyone (could fall in love with you)
# release_date                                    1964
# genre                                           rock
# Name: 18279, dtype: object
# ------------------------------
# C:\Users\Александр\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
predict('mose allison', "i don't worry about a thing", 10)
# Out:
# artist_name                    mose allison
# track_name      i don't worry about a thing
# release_date                           1962
# genre                                 blues
# Name: 10003, dtype: object
# ==============================
# artist_name     chuck berry
# track_name      thirty days
# release_date           1962
# genre                 blues
# Name: 10004, dtype: object
# ------------------------------
# artist_name     howlin' wolf
# track_name          spoonful
# release_date            1962
# genre                  blues
# Name: 10002, dtype: object
# ------------------------------
# artist_name                   aretha franklin
# track_name      ac-cent-tchu-ate the positive
# release_date                             1962
# genre                                   blues
# Name: 10005, dtype: object
# ------------------------------
# artist_name                    dinah washington
# track_name      lover man (oh where can you be)
# release_date                               1962
# genre                                     blues
# Name: 10006, dtype: object
# ------------------------------
# artist_name         howlin' wolf
# track_name      wang dang doodle
# release_date                1962
# genre                      blues
# Name: 10001, dtype: object
# ------------------------------
# artist_name                 mose allison
# track_name      your mind is on vacation
# release_date                        1962
# genre                              blues
# Name: 10000, dtype: object
# ------------------------------
# artist_name          john lee hooker
# track_name      blues before sunrise
# release_date                    1962
# genre                          blues
# Name: 10007, dtype: object
# ------------------------------
# artist_name     ella fitzgerald
# track_name            all of me
# release_date               1962
# genre                     blues
# Name: 10008, dtype: object
# ------------------------------
# artist_name                              john lee hooker
# track_name      keep your hands to yourself (she's mine)
# release_date                                        1962
# genre                                              blues
# Name: 9999, dtype: object
# ------------------------------
# artist_name      nina simone
# track_name      just in time
# release_date            1962
# genre                  blues
# Name: 10009, dtype: object
# ------------------------------
# C:\Users\Александр\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
predict('marilyn manson', 'deformography', 7)
# Out:
# artist_name     marilyn manson
# track_name       deformography
# release_date              1996
# genre                     rock
# Name: 20006, dtype: object
# ==============================
# artist_name     rage against the machine
# track_name         year of tha boomerang
# release_date                        1996
# genre                               rock
# Name: 20005, dtype: object
# ------------------------------
# artist_name       modest mouse
# track_name      novocain stain
# release_date              1996
# genre                     rock
# Name: 20007, dtype: object
# ------------------------------
# artist_name          george michael
# track_name      you have been loved
# release_date                   1996
# genre                          rock
# Name: 20004, dtype: object
# ------------------------------
# artist_name     modest mouse
# track_name             might
# release_date            1996
# genre                   rock
# Name: 20008, dtype: object
# ------------------------------
# artist_name         korn
# track_name      lowrider
# release_date        1996
# genre               rock
# Name: 20003, dtype: object
# ------------------------------
# artist_name     soundgarden
# track_name          ty cobb
# release_date           1996
# genre                  rock
# Name: 20009, dtype: object
# ------------------------------
# artist_name                                     weezer
# track_name      i just threw out the love of my dreams
# release_date                                      1996
# genre                                             rock
# Name: 20002, dtype: object
# ------------------------------
# C:\Users\Александр\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
# здесь можно посмотерть разные части датасета, чтобы выбрать примеры
start_row = 20000
end_row = 20030
data.iloc[start_row:end_row, :]
# Out:
#        level_0  index  Unnamed: 0               artist_name  \
# 20000    20000  25675       76527  rage against the machine
# 20001    20001  25676       76530               rod stewart
# 20002    20002  25678       76541                    weezer
# 20003    20003  25679       76545                      korn
# 20004    20004  25680       76549            george michael
# 20005    20005  25681       76550  rage against the machine
# 20006    20006  25682       76551            marilyn manson
# 20007    20007  25684       76553              modest mouse
# 20008    20008  25685       76561              modest mouse
# 20009    20009  25686       76563               soundgarden
# 20010    20010  25687       76567            marilyn manson
# 20011    20011  25688       76568                 metallica
# 20012    20012  25690       76572                    r.e.m.
# 20013    20013  25691       76573                    r.e.m.
# 20014    20014  25693       76582            marilyn manson
# 20015    20015  25694       76583                      korn
# 20016    20016  25695       76584            marilyn manson
# 20017    20017  25696       76587                      korn
# 20018    20018  25698       76590                      ween
# 20019    20019  25699       76591               soundgarden
# 20020    20020  25700       76592                 metallica
# 20021    20021  25702       76600                 radiohead
# 20022    20022  25703       76601                 sepultura
# 20023    20023  25705       76603                 metallica
# 20024    20024  25706       76606  rage against the machine
# 20025    20025  25707       76607  rage against the machine
# 20026    20026  25708       76609                      tool
# 20027    20027  25709       76610                      tool
# 20028    20028  25710       76613                      tool
# 20029    20029  25711       76614                      tool
#
#                                    track_name  release_date genre  \
# 20000                              wind below          1996  rock
# 20001                         when i need you          1996  rock
# 20002  i just threw out the love of my dreams          1996  rock
# 20003                                lowrider          1996  rock
# 20004                     you have been loved          1996  rock
# 20005                   year of tha boomerang          1996  rock
# 20006                           deformography          1996  rock
# 20007                          novocain stain          1996  rock
# 20008                                   might          1996  rock
# 20009                                 ty cobb          1996  rock
# 20010                                    1996          1996  rock
# 20011                            thorn within          1996  rock
# 20012                        e-bow the letter          1996  rock
# 20013                             electrolite          1996  rock
# 20014                             little horn          1996  rock
# 20015                                 swallow          1996  rock
# 20016                       man that you fear          1996  rock
# 20017                        no place to hide          1996  rock
# 20018                         i'm holding you          1996  rock
# 20019                               rhinosaur          1996  rock
# 20020                         poor twisted me          1996  rock
# 20021                          talk show host          1996  rock
# 20022                      roots bloody roots          1996  rock
# 20023                             bleeding me          1996  rock
# 20024                              roll right          1996  rock
# 20025                       people of the sun          1996  rock
# 20026                               third eye          1996  rock
# 20027                                   jimmy          1996  rock
# 20028                                      h.          1996  rock
# 20029                     hooker with a penis          1996  rock
#
#                                                   lyrics  len    dating  ...  \
# 20000  flip capital eclipse vocal tone sweat apocalyp...  123  0.000957  ...
# 20001  need close eye want heartbeat away need hold h...   69  0.025777  ...
# 20002  tall things throw dream eye ears blood tear br...   44  0.001548  ...
# 20003  shit friends drive lowrider lowrider little lo...   13  0.004785  ...
# 20004  take road past school change time think young ...   77  0.000822  ...
# 20005  sisters check line spend haiti state mind cast...  176  0.000578  ...
# 20006  wish fall fall hard fell insect decay little t...  113  0.000591  ...
# 20007  work tell stain memories yeah shoe remember so...   37  0.002288  ...
# 20008  break bone goddamn yesterday night break bone ...   11  0.004785  ...
# 20009  sit magic smoke mirror tire rubber fire watch ...  114  0.000532  ...
# 20010  light candle sinners world anti choice anti gi...   93  0.001422  ...
# 20011  forgive father sin guilty life feel brand sham...   42  0.001645  ...
# 20012  look fluorescent starry surprise ride go write...  165  0.021835  ...
# 20013  eye burn hole gasoline burn clean twentieth ce...   67  0.001170  ...
# 20014  apple pussy mouth dinner whore tumor mouth bur...   75  0.001012  ...
# 20015  fuck lock head pain know sure right sorrow swa...   79  0.001548  ...
# 20016  ants sugar muscle atrophy screen spread open s...  106  0.030429  ...
# 20017  face understand time dream stand right pride e...   66  0.000797  ...
# 20018  flyin flyin frame mind time erase seein seein ...   70  0.199357  ...
# 20019  stand enemy hang horn haste reverie kill charm...   45  0.001949  ...
# 20020  poor twist poor twist feast sympathy chew suff...   63  0.053196  ...
# 20021  want want explode float surface bird bird bird...   29  0.126287  ...
# 20022  root bloody root root bloody root root bloody ...   22  0.005263  ...
# 20023  dig dig dig better push stay push stay push st...  113  0.000634  ...
# 20024  check check check lick shoot stories shock lik...  140  0.032687  ...
# 20025  yeah people come yeah better turn bass check s...  112  0.000892  ...
# 20026  think drug good things believe drug good thing...   78  0.001012  ...
# 20027  like face stability suddenly look away leave d...   31  0.001880  ...
# 20028  come alive hold mirror sing songs snake look t...   44  0.001880  ...
# 20029  wear vans dope beastie nipple ring tattoo clai...   25  0.004049  ...
#
#         sadness  feelings  danceability  loudness  acousticness  \
# 20000  0.000957  0.000957      0.352323  0.667051      0.002579
# 20001  0.123891  0.000849      0.365320  0.621850      0.578313
# 20002  0.496256  0.001548      0.377234  0.813117      0.002218
# 20003  0.004785  0.004785      0.749810  0.729405      0.000774
# 20004  0.000822  0.000822      0.588433  0.514191      0.243975
# 20005  0.000578  0.000578      0.316582  0.654386      0.000500
# 20006  0.092487  0.000591      0.476876  0.669590      0.011144
# 20007  0.002288  0.002288      0.355572  0.691870      0.093573
# 20008  0.317103  0.004785      0.476876  0.733918      0.069879
# 20009  0.000532  0.000532      0.447633  0.676768      0.001174
# 20010  0.001422  0.125139      0.071808  0.760480      0.003423
# 20011  0.001645  0.036870      0.502870  0.764275      0.000015
# 20012  0.000470  0.000470      0.314416  0.699664      0.190762
# 20013  0.001170  0.001170      0.508285  0.722329      0.086947
# 20014  0.001012  0.001012      0.262428  0.710048      0.000904
# 20015  0.001548  0.001548      0.427055  0.669923      0.002760
# 20016  0.056365  0.000731      0.341492  0.641643      0.110441
# 20017  0.383235  0.000797      0.409726  0.748968      0.000781
# 20018  0.001880  0.112703      0.473627  0.478450      0.814257
# 20019  0.187250  0.104902      0.372902  0.688819      0.000472
# 20020  0.001170  0.067391      0.449800  0.792657      0.000098
# 20021  0.121247  0.002105      0.512618  0.552393      0.278112
# 20022  0.005263  0.005263      0.396729  0.743353      0.000337
# 20023  0.074200  0.000634      0.356655  0.758788      0.000894
# 20024  0.000763  0.013109      0.503953  0.707843      0.014055
# 20025  0.000892  0.000892      0.507202  0.751122      0.004085
# 20026  0.001012  0.042021      0.321997  0.665897      0.005872
# 20027  0.209981  0.001880      0.449800  0.702536      0.007489
# 20028  0.067248  0.001880      0.532113  0.663564      0.022288
# 20029  0.004049  0.004049      0.276508  0.725431      0.001284
#
#        instrumentalness   valence    energy       topic       age
# 20000          0.198381  0.432193  0.744737    violence  0.342857
# 20001          0.000000  0.176628  0.310289    romantic  0.342857
# 20002          0.000002  0.340478  0.963963     sadness  0.342857
# 20003          0.491903  0.976298  0.793787     obscene  0.342857
# 20004          0.072065  0.141591  0.243220  world/life  0.342857
# 20005          0.000428  0.509481  0.711703     obscene  0.342857
# 20006          0.000062  0.322960  0.851847    violence  0.342857
# 20007          0.009028  0.447650  0.816811  world/life  0.342857
# 20008          0.804656  0.210635  0.955955     sadness  0.342857
# 20009          0.431174  0.172506  0.989990    violence  0.342857
# 20010          0.219636  0.054617  0.970970  world/life  0.342857
# 20011          0.412955  0.646538  0.897895    violence  0.342857
# 20012          0.000248  0.313685  0.620609    violence  0.342857
# 20013          0.747976  0.471352  0.812807    violence  0.342857
# 20014          0.127530  0.135408  0.926925    violence  0.342857
# 20015          0.300607  0.383759  0.563550    violence  0.342857
# 20016          0.000012  0.113768  0.730722    violence  0.342857
# 20017          0.184211  0.626958  0.886883     sadness  0.342857
# 20018          0.192308  0.333265  0.182157  night/time  0.342857
# 20019          0.007743  0.728978  0.775769    violence  0.342857
# 20020          0.045547  0.466200  0.919917    violence  0.342857
# 20021          0.028846  0.495054  0.479463  night/time  0.342857
# 20022          0.042409  0.244641  0.874871  world/life  0.342857
# 20023          0.030466  0.230214  0.761754    violence  0.342857
# 20024          0.013462  0.441467  0.789783    violence  0.342857
# 20025          0.020951  0.703215  0.871868     obscene  0.342857
# 20026          0.477733  0.245672  0.628617  world/life  0.342857
# 20027          0.213563  0.444559  0.688679    violence  0.342857
# 20028          0.608300  0.069250  0.471455    violence  0.342857
# 20029          0.561741  0.258038  0.911909    violence  0.342857
#
# [30 rows x 33 columns]
